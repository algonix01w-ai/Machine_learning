# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics

# %% [raw]
# # Load the dataset___kaggle
# diabetes = load_diabetes()
# diabetes

# %%
df = pd.DataFrame(diabetes.data,columns = diabetes.feature_names)
df["target"]=diabetes.target

# %%
plt.figure(figsize=(10,6))
plt.scatter(df["bmi"],df["target"],alpha=0.4,c="r")

# %%
plt.title("graph")
x=plt.xlabel("x")
y=plt.ylabel("y")

# %%
x=df[['bmi']]
y=df[['target']]
x
# Out:
#           bmi
# 0    0.061696
# 1   -0.051474
# 2    0.044451
# 3   -0.011595
# 4   -0.036385
# ..        ...
# 437  0.019662
# 438 -0.015906
# 439 -0.015906
# 440  0.039062
# 441 -0.073030
#
# [442 rows x 1 columns]

# %%
#splting data
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size = 0.3,random_state=42)

# %%
# import and create data
model=LinearRegression()
#y=mx+c

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_[0]
# Out:
# array([988.41931249])

# %%
model.intercept_
# Out:
# array([151.04202449])

# %%
# y=mx+c
new_value=np.array([[1]])

# %%
pre=model.predict(new_value)
# Out:
# C:\Users\salon\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
pre
# Out:
# array([[1139.46133698]])

# %%
x=model.coef_[0]
y=model.intercept_

# %%
plt.title("graph")
x=plt.xlabel("x")
y=plt.ylabel("y")

# %%
# plt.figure(figsize=(10,6))
# plt.scatter(x,y,alpha=0.4,c="r")

# %%
mean_absolute_error= metrics.mean_absolute_error(y_test, pre)
mean_square_error= metrics.mean_squared_error(y_test , pre)
root_mean_square=np.sqrt(mean_squared_error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 mean_absolute_error= metrics.mean_absolute_error(y_test, pre)
#       2 mean_square_error= metrics.mean_squared_error(y_test , pre)
#       3 root_mean_square=np.sqrt(mean_squared_error)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
# ...

# %%
mean_absolute_error
# Out:
# <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>

# %%
mean_square_error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 mean_square_error
#
# NameError: name 'mean_square_error' is not defined

# %%
root_mean_square
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 root_mean_square
#
# NameError: name 'root_mean_square' is not defined
