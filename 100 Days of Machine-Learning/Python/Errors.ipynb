# %%
for i in [1,2,3,4,6]:
  print(i)
 print(i)
# Out:
#   File <string>:3
#     print(i)
#             ^
# IndentationError: unindent does not match any outer indentation level

# %%
for i in [1,2,3,4,6]:
    print(i)
      print(i)
# Out:
#   Cell In[9], line 3
#     print(i)
#     ^
# IndentationError: unexpected indent

# %%
for i in [1,2,3,4,6]:
    # print(i)
    '''
    '''

    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6

# %%
x="\tju"
len(x)
# Out:
# 3

# %% [markdown]
# ## Raw string

# %%
x=r"\tmn"
len(x)
# Out:
# 4

# %%
s={
    "saloni":434,
    ("s","sa","salo","saloni"): "yes"
}
s
# Out:
# {'saloni': 434, ('s', 'sa', 'salo', 'saloni'): 'yes'}

# %%
434 in s.values()
# Out:
# True
